# %%
# pip install beautifulsoup4
# !pip install geopy
# !pip install gpxpy
# !pip install mplleaflet
# Out:
# Collecting mplleaflet
#   Downloading https://files.pythonhosted.org/packages/05/b3/e68ff575ef0872e096878c75f602e76b06ca44d7038d69d867c7b800745b/mplleaflet-0.0.5.tar.gz
# Requirement already satisfied: jinja2 in /home/andre/anaconda3/lib/python3.7/site-packages (from mplleaflet) (2.10)
# Requirement already satisfied: six in /home/andre/anaconda3/lib/python3.7/site-packages (from mplleaflet) (1.12.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /home/andre/anaconda3/lib/python3.7/site-packages (from jinja2->mplleaflet) (1.1.1)
# Building wheels for collected packages: mplleaflet
#   Building wheel for mplleaflet (setup.py) ... done
#   Stored in directory: /home/andre/.cache/pip/wheels/bf/fd/0b/0513de62c339c4a56e2234aa42a5d06e6660a4446fdae7b796
# Successfully built mplleaflet
# Installing collected packages: mplleaflet
# Successfully installed mplleaflet-0.0.5

# %%
import gpxpy
import pandas as pd
import geopy
from geopy.distance import geodesic
from geopy.geocoders import Nominatim
import matplotlib.pyplot as plt
import mplleaflet
import numpy as np
import glob
import datetime
from datetime import datetime

# %%
gpx_arr=[]
segments=[]
data = []
for name in glob.glob('gpx/*.gpx'):
    print(name)
    gpx_arr.append(gpxpy.parse(open(name)))
    
for gpx0 in gpx_arr:
    segments.append(gpx0.tracks[0].segments[0])
    
for seg in segments:
    for point_idx, point in enumerate(seg.points):
        data.append([point.longitude, point.latitude,
                 point.elevation, point.time, seg.get_speed(point_idx)])
# Out:
# gpx/20190407.gpx
# gpx/20191008.gpx
# gpx/20191020.gpx
# gpx/20190907.gpx
# gpx/20191022.gpx
# gpx/20191006.gpx
# gpx/20190112.gpx
# gpx/20190903.gpx
# gpx/20190428.gpx
# gpx/20190113.gpx
# gpx/20191018.gpx
# gpx/20190823.gpx
# gpx/20190902.gpx
# gpx/20191009.gpx
# gpx/20191017.gpx
# gpx/20190429.gpx
# gpx/20190502.gpx
# gpx/20191016.gpx
# gpx/20191025.gpx
# gpx/20190526.gpx
# gpx/20191021.gpx
# gpx/20191007.gpx
# gpx/20190906.gpx
# gpx/20190304.gpx
# gpx/20190306.gpx
# gpx/20190904.gpx
# gpx/20190905.gpx
# gpx/20190430.gpx
# gpx/20190501.gpx
# gpx/20190408.gpx
# gpx/20190111.gpx
# gpx/20191019.gpx
# gpx/20191004.gpx
# gpx/20191005.gpx

# %%
columns = ['Longitude', 'Latitude', 'Altitude', 'Time', 'Speed']
df = pd.DataFrame(data, columns=columns)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2802 entries, 0 to 2801
# Data columns (total 5 columns):
# Longitude    2802 non-null float64
# Latitude     2802 non-null float64
# Altitude     2407 non-null float64
# Time         2802 non-null datetime64[ns, SimpleTZ("Z")]
# Speed        2800 non-null float64
# dtypes: datetime64[ns, SimpleTZ("Z")](1), float64(4)
# memory usage: 109.5 KB

# %%
lo_origem = []
la_origem = []
lo_destino = []
la_destino = []
velocidade_media = []
distancia = []
altitude_origem = []
altitude_destino = []
hora_origem = []
hora_destino = []
for idx in range(1, len(df)):
    lo_origem.append(df.iloc[idx-1].Longitude)
    la_origem.append(df.iloc[idx-1].Latitude)
    lo_destino.append(df.iloc[idx].Longitude)
    la_destino.append(df.iloc[idx].Latitude)
    distancia.append(geodesic([df.iloc[idx-1].Longitude,df.iloc[idx-1].Latitude],[df.iloc[idx].Longitude, df.iloc[idx].Latitude]).km)
    velocidade_media.append(np.mean([df.iloc[idx-1].Speed,df.iloc[idx].Speed]))
    altitude_origem.append(df.iloc[idx-1].Altitude)
    altitude_destino.append(df.iloc[idx].Altitude)
    hora_origem.append(df.iloc[idx-1].Time)
    hora_destino.append(df.iloc[idx].Time)

df_trk = pd.DataFrame()
df_trk['lo_origem'] = lo_origem
df_trk['la_origem'] = la_origem
df_trk['lo_destino'] = lo_origem
df_trk['la_destino'] = la_destino

df_trk['velocidade_media'] = velocidade_media
df_trk['distancia'] = distancia

df_trk['altitude_origem'] = altitude_origem
df_trk['altitude_destino'] = altitude_destino
df_trk['hora_origem'] = hora_origem
df_trk['hora_destino'] = hora_destino



df_trk = df_trk.fillna(0)
df_trk.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2801 entries, 0 to 2800
# Data columns (total 10 columns):
# lo_origem           2801 non-null float64
# la_origem           2801 non-null float64
# lo_destino          2801 non-null float64
# la_destino          2801 non-null float64
# velocidade_media    2801 non-null float64
# distancia           2801 non-null float64
# altitude_origem     2801 non-null float64
# altitude_destino    2801 non-null float64
# hora_origem         2801 non-null datetime64[ns, SimpleTZ("Z")]
# hora_destino        2801 non-null datetime64[ns, SimpleTZ("Z")]
# dtypes: datetime64[ns, SimpleTZ("Z")](2), float64(8)
# memory usage: 218.9 KB

# %%
df_trk['duracao'] = (df_trk.hora_destino - df_trk.hora_origem)

# %%
df_trk
# Out:
#       lo_origem  la_origem  lo_destino  la_destino  velocidade_media  \
# 0    -38.462978 -12.998858  -38.462978  -13.000152          5.602054
# 1    -38.459967 -13.000152  -38.459967  -13.002398          4.735510
# 2    -38.458522 -13.002398  -38.458522  -12.999846          5.589817
# 3    -38.459673 -12.999846  -38.459673  -12.996312          8.086026
# 4    -38.464476 -12.996312  -38.464476  -12.992601          7.979355
# 5    -38.466324 -12.992601  -38.466324  -12.989288          5.808185
# 6    -38.466517 -12.989288  -38.466517  -12.988121          3.528178
# 7    -38.466972 -12.988121  -38.466972  -12.987981          2.454825
# 8    -38.468121 -12.987981  -38.468121  -12.988873          6.111298
# 9    -38.470224 -12.988873  -38.470224  -12.994839         12.705794
# 10   -38.475915 -12.994839  -38.475915  -13.000516         14.671893
# 11   -38.483152 -13.000516  -38.483152  -13.005325         12.471871
# 12   -38.486250 -13.005325  -38.486250  -13.007766         11.426955
# 13   -38.492696 -13.007766  -38.492696  -13.007490         11.531854
# 14   -38.498637 -13.007490  -38.498637  -13.002273         11.150134
# 15   -38.503341 -13.002273  -38.503341  -12.998563          9.430067
# 16   -38.506264 -12.998563  -38.506264  -12.994420          7.882807
# 17   -38.507062 -12.994420  -38.507062  -12.995387          9.276508
# 18   -38.511142 -12.995387  -38.511142  -12.995009         11.615663
# 19   -38.519275 -12.995009  -38.519275  -12.995204         12.538049
# 20   -38.524823 -12.995204  -38.524823  -12.986860         13.809019
# 21   -38.522920 -12.986860  -38.522920  -12.980439         13.168722
# 22   -38.518621 -12.980439  -38.518621  -12.976395          8.255592
# 23   -38.515802 -12.976395  -38.515802  -12.975674          4.963662
# 24   -38.515178 -12.975674  -38.515178  -12.971472          6.531591
# 25   -38.512495 -12.971472  -38.512495  -12.968562          9.362571
# 26   -38.509772 -12.968562  -38.509772  -12.962458         11.060203
# 27   -38.504965 -12.962458  -38.504965  -12.958344         11.291573
# 28   -38.502362 -12.958344  -38.502362  -12.951372         10.998384
# 29   -38.500943 -12.951372  -38.500943  -12.946633          9.179331
# ...         ...        ...         ...         ...               ...
# 2771 -38.501428 -12.951784  -38.501428  -12.958881         11.445053
# 2772 -38.504131 -12.958881  -38.504131  -12.961154          8.671485
# 2773 -38.506529 -12.961154  -38.506529  -12.965393          7.668748
# 2774 -38.508916 -12.965393  -38.508916  -12.964540          7.909942
# 2775 -38.505205 -12.964540  -38.505205  -12.969312          6.486302
# 2776 -38.504057 -12.969312  -38.504057  -12.970253          2.969833
# 2777 -38.504198 -12.970253  -38.504198  -12.971194          0.960068
# 2778 -38.504327 -12.971194  -38.504327  -12.972125          2.429367
# 2779 -38.504379 -12.972125  -38.504379  -12.968576          6.530324
# 2780 -38.503860 -12.968576  -38.503860  -12.962169          9.561817
# 2781 -38.504989 -12.962169  -38.504989  -12.958773         10.579210
# 2782 -38.502197 -12.958773  -38.502197  -12.963005         13.079776
# 2783 -38.495264 -12.963005  -38.495264  -12.968064         14.558341
# 2784 -38.488420 -12.968064  -38.488420  -12.969332         11.486228
# 2785 -38.481029 -12.969332  -38.481029  -12.970532          9.278549
# 2786 -38.478879 -12.970532  -38.478879  -12.977549         12.875650
# 2787 -38.474304 -12.977549  -38.474304  -12.980299         13.445354
# 2788 -38.465477 -12.980299  -38.465477  -12.978281         10.747531
# 2789 -38.461466 -12.978281  -38.461466  -12.983066         12.805039
# 2790 -38.453904 -12.983066  -38.453904  -12.989815         14.401713
# 2791 -38.450099 -12.989815  -38.450099  -12.997179         12.285786
# 2792 -38.450609 -12.997179  -38.450609  -13.001506          8.876472
# 2793 -38.451388 -13.001506  -38.451388  -13.002479          5.485326
# 2794 -38.454390 -13.002479  -38.454390  -13.001388          3.027667
# 2795 -38.455016 -13.001388  -38.455016  -13.000819          2.881700
# 2796 -38.455772 -13.000819  -38.455772  -13.000782          4.077095
# 2797 -38.459003 -13.000782  -38.459003  -13.001786          3.597198
# 2798 -38.460401 -13.001786  -38.460401  -13.001219          2.915850
# 2799 -38.461659 -13.001219  -38.461659  -12.999908          2.721019
# 2800 -38.463157 -12.999908  -38.463157  -12.999000          1.759368
#
#       distancia  altitude_origem  altitude_destino      hora_origem  \
# 0      0.352872        28.000000         15.000000         20:16:48
# 1      0.253260        15.000000          8.000000         20:17:49
# 2      0.256726         8.000000          8.000000         20:18:50
# 3      0.615991         8.000000          3.000000         20:20:21
# 4      0.383429         3.000000         -3.000000         20:21:22
# 5      0.289893        -3.000000         -7.000000         20:22:23
# 6      0.113735        -7.000000          0.000000         20:23:23
# 7      0.128161         0.000000          1.000000  20:24:04.590000
# 8      0.246131         1.000000          4.000000         20:25:52
# 9      0.818588         4.000000          9.000000         20:26:53
# 10     0.943792         9.000000          6.000000         20:27:53
# 11     0.542492         6.000000         -3.000000         20:28:54
# 12     0.746548        -3.000000         -7.000000         20:29:54
# 13     0.659974        -7.000000          8.000000         20:30:55
# 14     0.692607         8.000000         13.000000         20:31:56
# 15     0.458209        13.000000         15.000000         20:32:57
# 16     0.372146        15.000000         10.000000         20:33:57
# 17     0.460634        10.000000         11.000000         20:34:58
# 18     0.903435        11.000000         25.000000         20:35:59
# 19     0.616091        25.000000         27.000000         20:37:00
# 20     0.757650        27.000000         39.000000         20:38:00
# 21     0.735767        39.000000          7.000000         20:39:01
# 22     0.471502         7.000000         -6.000000         20:40:02
# 23     0.093531        -6.000000         -5.000000         20:41:02
# 24     0.472199        -5.000000          4.000000         20:43:02
# 25     0.394750         4.000000          3.000000         20:44:03
# 26     0.753830         3.000000         -4.000000         20:45:04
# 27     0.460740        -4.000000          0.000000         20:46:05
# 28     0.628220         0.000000        -12.000000         20:47:05
# 29     0.413442       -12.000000         -6.000000         20:48:05
# ...         ...              ...               ...              ...
# 2771   0.687974        -5.000000         -7.000000         21:20:55
# 2772   0.331903        -7.000000         -4.000000         21:21:56
# 2773   0.454952        -4.000000         -5.000000         21:22:57
# 2774   0.418612        -5.000000          0.000000         21:23:57
# 2775   0.435337         0.000000         27.000000         21:24:58
# 2776   0.083552        27.000000         24.000000         21:25:58
# 2777   0.083332        24.000000         25.000000         21:27:49
# 2778   0.081433        25.000000         26.000000         21:29:51
# 2779   0.314928        26.000000         33.000000         21:31:21
# 2780   0.572753        33.000000         -5.000000         21:32:22
# 2781   0.428725        -5.000000          7.000000         21:33:23
# 2782   0.853593         7.000000         11.000000         21:34:24
# 2783   0.878580        11.000000          5.000000         21:35:25
# 2784   0.827907         5.000000          4.000000         21:36:26
# 2785   0.260602         4.000000          2.000000         21:37:28
# 2786   0.795504         2.000000          1.000000         21:38:29
# 2787   1.008826         1.000000          2.000000         21:39:30
# 2788   0.478801         2.000000          7.000000         21:40:30
# 2789   0.937558         7.000000          6.000000         21:42:06
# 2790   0.724879         6.000000          2.000000         21:43:07
# 2791   0.645290         2.000000          3.000000         21:44:08
# 2792   0.387533         3.000000         -7.000000         21:45:09
# 2793   0.343873        -7.000000         14.900001         21:46:09
# 2794   0.117850        14.900001          3.000000  21:47:09.744000
# 2795   0.097474         3.000000          2.000000         21:48:10
# 2796   0.358716         2.000000          8.000000         21:49:10
# 2797   0.178187         8.000000          6.000000         21:50:11
# 2798   0.148162         6.000000         11.000000         21:51:12
# 2799   0.201864        11.000000         20.000000         21:52:13
# 2800   0.087646        20.000000         18.100000         21:53:13
#
#          hora_destino         duracao        data
# 0            20:17:49        00:01:01  2019-04-07
# 1            20:18:50        00:01:01  2019-04-07
# 2            20:20:21        00:01:31  2019-04-07
# 3            20:21:22        00:01:01  2019-04-07
# 4            20:22:23        00:01:01  2019-04-07
# 5            20:23:23        00:01:00  2019-04-07
# 6     20:24:04.590000 00:00:41.590000  2019-04-07
# 7            20:25:52 00:01:47.410000  2019-04-07
# 8            20:26:53        00:01:01  2019-04-07
# 9            20:27:53        00:01:00  2019-04-07
# 10           20:28:54        00:01:01  2019-04-07
# 11           20:29:54        00:01:00  2019-04-07
# 12           20:30:55        00:01:01  2019-04-07
# 13           20:31:56        00:01:01  2019-04-07
# 14           20:32:57        00:01:01  2019-04-07
# 15           20:33:57        00:01:00  2019-04-07
# 16           20:34:58        00:01:01  2019-04-07
# 17           20:35:59        00:01:01  2019-04-07
# 18           20:37:00        00:01:01  2019-04-07
# 19           20:38:00        00:01:00  2019-04-07
# 20           20:39:01        00:01:01  2019-04-07
# 21           20:40:02        00:01:01  2019-04-07
# 22           20:41:02        00:01:00  2019-04-07
# 23           20:43:02        00:02:00  2019-04-07
# 24           20:44:03        00:01:01  2019-04-07
# 25           20:45:04        00:01:01  2019-04-07
# 26           20:46:05        00:01:01  2019-04-07
# 27           20:47:05        00:01:00  2019-04-07
# 28           20:48:05        00:01:00  2019-04-07
# 29           20:49:06        00:01:01  2019-04-07
# ...               ...             ...         ...
# 2771         21:21:56        00:01:01  2019-10-05
# 2772         21:22:57        00:01:01  2019-10-05
# 2773         21:23:57        00:01:00  2019-10-05
# 2774         21:24:58        00:01:01  2019-10-05
# 2775         21:25:58        00:01:00  2019-10-05
# 2776         21:27:49        00:01:51  2019-10-05
# 2777         21:29:51        00:02:02  2019-10-05
# 2778         21:31:21        00:01:30  2019-10-05
# 2779         21:32:22        00:01:01  2019-10-05
# 2780         21:33:23        00:01:01  2019-10-05
# 2781         21:34:24        00:01:01  2019-10-05
# 2782         21:35:25        00:01:01  2019-10-05
# 2783         21:36:26        00:01:01  2019-10-05
# 2784         21:37:28        00:01:02  2019-10-05
# 2785         21:38:29        00:01:01  2019-10-05
# 2786         21:39:30        00:01:01  2019-10-05
# 2787         21:40:30        00:01:00  2019-10-05
# 2788         21:42:06        00:01:36  2019-10-05
# 2789         21:43:07        00:01:01  2019-10-05
# 2790         21:44:08        00:01:01  2019-10-05
# 2791         21:45:09        00:01:01  2019-10-05
# 2792         21:46:09        00:01:00  2019-10-05
# 2793  21:47:09.744000 00:01:00.744000  2019-10-05
# 2794         21:48:10 00:01:00.256000  2019-10-05
# 2795         21:49:10        00:01:00  2019-10-05
# 2796         21:50:11        00:01:01  2019-10-05
# 2797         21:51:12        00:01:01  2019-10-05
# 2798         21:52:13        00:01:01  2019-10-05
# 2799         21:53:13        00:01:00  2019-10-05
# 2800  21:54:48.851000 00:01:35.851000  2019-10-05
#
# [2801 rows x 12 columns]

# %%
# https://pandas.pydata.org/pandas-docs/version/0.15.2/api.html
# The day of the week with Monday=0, Sunday=6
df_trk.groupby(df_trk.hora_origem.dt.day_name())['distancia'].sum()
# Out:
# hora_origem
# Friday       111.935541
# Monday       134.066800
# Saturday     258.067187
# Sunday       199.865823
# Thursday      90.984115
# Tuesday       91.069271
# Wednesday    185.701567
# Name: distancia, dtype: float64

# %%
import calendar

# df_trk[['lo_origem','la_origem','hora_origem']]
# df_trk.hora_destino.dt.date
# df_trk.hora_origem.dt.time
df_trk.hora_destino.dt.time

# %%
plt.plot(df_trk.lo_origem,df_trk.la_origem)
mplleaflet.show()

# %%
geolocator = Nominatim(user_agent="britto_app")
geopy.geocoders.options.default_timeout = 120

# %%
end2 = []
for index, row in df_trk.iterrows():
    end2.append(geolocator.reverse(str(row["la_origem"]) +','+ str(row["lo_origem"])))
# Out:
# ---------------------------------------------------------------------------
# timeout                                   Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/urllib/request.py in do_open(self, http_class, req, **http_conn_args)
#    1316                 h.request(req.get_method(), req.selector, req.data, headers,
# -> 1317                           encode_chunked=req.has_header('Transfer-encoding'))
#    1318             except OSError as err: # timeout error
#
# ~/anaconda3/lib/python3.7/http/client.py in request(self, method, url, body, headers, encode_chunked)
#    1228         """Send a complete request to the server."""
# -> 1229         self._send_request(method, url, body, headers, encode_chunked)
#    1230
#
# ~/anaconda3/lib/python3.7/http/client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1274             body = _encode(body, 'body')
# -> 1275         self.endheaders(body, encode_chunked=encode_chunked)
#    1276
#
# ~/anaconda3/lib/python3.7/http/client.py in endheaders(self, message_body, encode_chunked)
#    1223             raise CannotSendHeader()
# -> 1224         self._send_output(message_body, encode_chunked=encode_chunked)
#    1225
#
# ~/anaconda3/lib/python3.7/http/client.py in _send_output(self, message_body, encode_chunked)
#    1015         del self._buffer[:]
# -> 1016         self.send(msg)
#    1017
#
# ~/anaconda3/lib/python3.7/http/client.py in send(self, data)
#     955             if self.auto_open:
# --> 956                 self.connect()
#     957             else:
#
# ~/anaconda3/lib/python3.7/http/client.py in connect(self)
#    1391             self.sock = self._context.wrap_socket(self.sock,
# -> 1392                                                   server_hostname=server_hostname)
#    1393
#
# ~/anaconda3/lib/python3.7/ssl.py in wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, session)
#     411             context=self,
# --> 412             session=session
#     413         )
#
# ~/anaconda3/lib/python3.7/ssl.py in _create(cls, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, context, session)
#     852                         raise ValueError("do_handshake_on_connect should not be specified for non-blocking sockets")
# --> 853                     self.do_handshake()
#     854             except (OSError, ValueError):
#
# ~/anaconda3/lib/python3.7/ssl.py in do_handshake(self, block)
#    1116                 self.settimeout(None)
# -> 1117             self._sslobj.do_handshake()
#    1118         finally:
#
# timeout: _ssl.c:1039: The handshake operation timed out
#
# During handling of the above exception, another exception occurred:
#
# URLError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/geopy/geocoders/base.py in _call_geocoder(self, url, timeout, raw, requester, deserializer, **kwargs)
#     354         try:
# --> 355             page = requester(req, timeout=timeout, **kwargs)
#     356         except Exception as error:
#
# ~/anaconda3/lib/python3.7/urllib/request.py in open(self, fullurl, data, timeout)
#     524
# --> 525         response = self._open(req, data)
#     526
#
# ~/anaconda3/lib/python3.7/urllib/request.py in _open(self, req, data)
#     542         result = self._call_chain(self.handle_open, protocol, protocol +
# --> 543                                   '_open', req)
#     544         if result:
#
# ~/anaconda3/lib/python3.7/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     502             func = getattr(handler, meth_name)
# --> 503             result = func(*args)
#     504             if result is not None:
#
# ~/anaconda3/lib/python3.7/urllib/request.py in https_open(self, req)
#    1359             return self.do_open(http.client.HTTPSConnection, req,
# -> 1360                 context=self._context, check_hostname=self._check_hostname)
#    1361
#
# ~/anaconda3/lib/python3.7/urllib/request.py in do_open(self, http_class, req, **http_conn_args)
#    1318             except OSError as err: # timeout error
# -> 1319                 raise URLError(err)
#    1320             r = h.getresponse()
#
# URLError: <urlopen error _ssl.c:1039: The handshake operation timed out>
#
# During handling of the above exception, another exception occurred:
#
# GeocoderTimedOut                          Traceback (most recent call last)
# <ipython-input-672-c262c04d9603> in <module>
#       1 end2 = []
#       2 for index, row in df_trk.iterrows():
# ----> 3     end2.append(geolocator.reverse(str(row["la_origem"]) +','+ str(row["lo_origem"])))
#
# ~/anaconda3/lib/python3.7/site-packages/geopy/geocoders/osm.py in reverse(self, query, exactly_one, timeout, language, addressdetails)
#     447
#     448         return self._parse_json(
# --> 449             self._call_geocoder(url, timeout=timeout), exactly_one
#     450         )
#     451
#
# ~/anaconda3/lib/python3.7/site-packages/geopy/geocoders/base.py in _call_geocoder(self, url, timeout, raw, requester, deserializer, **kwargs)
#     376             elif isinstance(error, URLError):
#     377                 if "timed out" in message:
# --> 378                     raise GeocoderTimedOut('Service timed out')
#     379                 elif "unreachable" in message:
#     380                     raise GeocoderUnavailable('Service not available')
#
# GeocoderTimedOut: Service timed out

# %% [markdown]
# Busca das informações de postos de gasolina

# %%
import requests
from bs4 import BeautifulSoup

# %%
url='https://www.gasnet.com.br/postos_gnv_lista.asp?nomestado=Bahia'
page = requests.get(url)

# %%
soup = BeautifulSoup(page.text, 'html.parser')

# %%
lista_post_scrp = []
for link in soup.find_all('a'):
    lista_post_scrp.append(link.get('href'))

# %%
reg = []
for lst in lista_post_scrp:
    reg.append(lst.split('&'))
#     for l in lst.split('&'):
#        print(l)

# %%
reg = reg[1:]

# %%
aux = []
for rg in reg:
    rg = rg[1:]
    aux.append(rg)

# %%
df_postos = pd.DataFrame(aux)

# %%
linha = []
registro = []
for a in aux:
    print('-- linha --')    
    linha.append(registro)
    registro = []
    for cmp in a:
        registro.append(cmp.split('=')[1])
        print(registro)
        
linha = linha[1:]
# Out:
# -- linha --
# ['Central Posto']
# ['Central Posto', 'BR']
# ['Central Posto', 'BR', 'Rodovia BR-101 Km 110.5 - s/nÂº,Alagoinhas,Bahia']
# -- linha --
# ['Posto Gnc Alagoinhas']
# ['Posto Gnc Alagoinhas', 'BRANCA']
# ['Posto Gnc Alagoinhas', 'BRANCA', 'Av. Juracy MagalhÃ£es, s/nÂº,Alagoinhas,Bahia']
# -- linha --
# ['Posto Guaraiuba']
# ['Posto Guaraiuba', 'BRANCA']
# ['Posto Guaraiuba', 'BRANCA', 'Via Parafuso, s/nÂº, Km 13,5,CamaÃ§ari,Bahia']
# -- linha --
# ['Posto Interlagos']
# ['Posto Interlagos', 'BR']
# ['Posto Interlagos', 'BR', 'Rodovia BA-099, Estrada do CÃ´co, Km 21, s/nÂº,CamaÃ§ari,Bahia']
# -- linha --
# ['Posto Radial B']
# ['Posto Radial B', 'BR']
# ['Posto Radial B', 'BR', 'Rua Manoel Alfredo MercÃªs, 783,CamaÃ§ari,Bahia']
# -- linha --
# ['Posto Ondas']
# ['Posto Ondas', 'BR']
# ['Posto Ondas', 'BR', 'Estrada do CÃ´co, Km 22,CamaÃ§ari,Bahia']
# -- linha --
# ['Posto Tvl 2']
# ['Posto Tvl 2', 'BRANCA']
# ['Posto Tvl 2', 'BRANCA', 'Rodovia BA-535, Km 15 (Via Parafuso),CamaÃ§ari,Bahia']
# -- linha --
# ['Posto Trevo']
# ['Posto Trevo', 'BR']
# ['Posto Trevo', 'BR', 'Av. Perimetral, s/nÂº,CamaÃ§ari,Bahia']
# -- linha --
# ['Posto Ampr']
# ['Posto Ampr', 'BRANCA']
# ['Posto Ampr', 'BRANCA', 'Av. Jorge Amado (Av.Leste), s/nÂº,CamaÃ§ari,Bahia']
# -- linha --
# ['Posto Parafuso']
# ['Posto Parafuso', 'BRANCA']
# ['Posto Parafuso', 'BRANCA', 'Rua Lateral de Dentro, s/nÂº - Km 16.3 - Lotes 4 a 8,CamaÃ§ari,Bahia']
# -- linha --
# ['Posto Millenium']
# ['Posto Millenium', 'BRANCA']
# ['Posto Millenium', 'BRANCA', 'Rodovia BA-522, Km 08 s/nÂº,Candeias,Bahia']
# -- linha --
# ['Posto Rio Ventura']
# ['Posto Rio Ventura', 'BRANCA']
# ['Posto Rio Ventura', 'BRANCA', 'Estrada de LigaÃ§Ã£o BA-533 /BA-093 - Km 1,5,Catu,Bahia']
# -- linha --
# ['Posto SÃ£o Luiz']
# ['Posto SÃ£o Luiz', 'BRANCA']
# ['Posto SÃ£o Luiz', 'BRANCA', 'Rodovia BR-324 Km 89 s/nÂº,ConceiÃ§Ã£o do JacuÃ\xadpe,Bahia']
# -- linha --
# ['Posto CajÃ¡']
# ['Posto CajÃ¡', 'BRANCA']
# ['Posto CajÃ¡', 'BRANCA', 'Av. GetÃºlio Vargas, 2.860,Cruz das Almas,Bahia']
# -- linha --
# ['Posto Casa Nova (gnc)']
# ['Posto Casa Nova (gnc)', 'BRANCA']
# ['Posto Casa Nova (gnc)', 'BRANCA', 'Rua JosÃ© LeÃ£o, 34,Dias DÂ´Ã\x81v,Bahia']
# -- linha --
# ['Posto Shangai']
# ['Posto Shangai', 'BR']
# ['Posto Shangai', 'BR', 'Rodovia BR-324, Km 98, s/nÂº,Feira de Santana,Bahia']
# -- linha --
# ['Posto Portal do SertÃ£o']
# ['Posto Portal do SertÃ£o', 'SHELL']
# ['Posto Portal do SertÃ£o', 'SHELL', 'Rodovia BR-324, Km 01 - Sentido Feira de Santana-Salvador,Feira de Santana,Bahia']
# -- linha --
# ['Posto Kalilandia Ii']
# ['Posto Kalilandia Ii', 'SHELL']
# ['Posto Kalilandia Ii', 'SHELL', 'Av. Presidente Dutra, 1.320,Feira de Santana,Bahia']
# -- linha --
# ['Posto Petromasa']
# ['Posto Petromasa', 'BRANCA']
# ['Posto Petromasa', 'BRANCA', 'Av. Presidente Dutra, 2.325,Feira de Santana,Bahia']
# -- linha --
# ['Posto Cs Aven']
# ['Posto Cs Aven', 'BR']
# ['Posto Cs Aven', 'BR', 'Av. Sampaio, 788,Feira de Santana,Bahia']
# -- linha --
# ['Posto Gnc Feira']
# ['Posto Gnc Feira', 'BRANCA']
# ['Posto Gnc Feira', 'BRANCA', 'Rodovia BR-324 - Km 102, Lote 6, Qd.E,Feira de Santana,Bahia']
# -- linha --
# ['Posto Astec']
# ['Posto Astec', 'SHELL']
# ['Posto Astec', 'SHELL', 'Av. Eduardo Froes da Mota, 1.197,Feira de Santana,Bahia']
# -- linha --
# ['Auto Posto Gasauto']
# ['Auto Posto Gasauto', 'BRANCA']
# ['Auto Posto Gasauto', 'BRANCA', 'Estrada Feira - SÃ£o GonÃ§alo, s/nÂº,Feira de Santana,Bahia']
# -- linha --
# ['Posto Universal']
# ['Posto Universal', 'BRANCA']
# ['Posto Universal', 'BRANCA', 'Rua Santo Antonio, Lotes 26/27,Itabuna,Bahia']
# -- linha --
# ['Posto Rio Mucuri']
# ['Posto Rio Mucuri', 'BRANCA']
# ['Posto Rio Mucuri', 'BRANCA', 'Rodovia BR-101 km 941,8,Mucuri,Bahia']
# -- linha --
# ['Posto St']
# ['Posto St', 'BR']
# ['Posto St', 'BR', 'Rua EdÃ\xadstio Ponde, 474,Salvador,Bahia']
# -- linha --
# ['Posto Amaral']
# ['Posto Amaral', 'BRANCA']
# ['Posto Amaral', 'BRANCA', 'Av. Visconde de ItaboraÃ\xad, 30,Salvador,Bahia']
# -- linha --
# ['Posto SÃ£o Judas Tadeu']
# ['Posto SÃ£o Judas Tadeu', 'BRANCA']
# ['Posto SÃ£o Judas Tadeu', 'BRANCA', 'Rua Quinta dos LÃ¡zaros, 22,Salvador,Bahia']
# -- linha --
# ['Posto Dois LeÃµes']
# ['Posto Dois LeÃµes', 'BR']
# ['Posto Dois LeÃµes', 'BR', 'Rua CÃ´nego Pereira Marinho, 31,Salvador,Bahia']
# -- linha --
# ['Posto Gas On L']
# ['Posto Gas On L', 'BRANCA']
# ['Posto Gas On L', 'BRANCA', 'Av. Heitor Dias, 148,Salvador,Bahia']
# -- linha --
# ['Posto ItaicÃª']
# ['Posto ItaicÃª', 'BRANCA']
# ['Posto ItaicÃª', 'BRANCA', 'Av. MÃ¡rio Leal ferreira, 252,Salvador,Bahia']
# -- linha --
# ['Posto Santa']
# ['Posto Santa', 'BRANCA']
# ['Posto Santa', 'BRANCA', 'Av. MÃ¡rio Leal Ferreira, s/nÂº,Salvador,Bahia']
# -- linha --
# ['Posto BonocÃ´']
# ['Posto BonocÃ´', 'BR']
# ['Posto BonocÃ´', 'BR', 'Av. MÃ¡rio Leal Ferreira, 509,Salvador,Bahia']
# -- linha --
# ['Posto Mataripe I']
# ['Posto Mataripe I', 'BR']
# ['Posto Mataripe I', 'BR', 'Av. MÃ¡rio Leal Ferreira, 2.230,Salvador,Bahia']
# -- linha --
# ['Posto Coomasal']
# ['Posto Coomasal', 'BR']
# ['Posto Coomasal', 'BR', 'Av. Vale do OgunjÃ¡, 1.226,Salvador,Bahia']
# -- linha --
# ['Posto Iguatemi']
# ['Posto Iguatemi', 'BR']
# ['Posto Iguatemi', 'BR', 'Av. AntÃ´nio Carlos MagalhÃ£es, s/nÂº,Salvador,Bahia']
# -- linha --
# ['Posto Mataripe V']
# ['Posto Mataripe V', 'BR']
# ['Posto Mataripe V', 'BR', 'Av.AntÃ´nio Carlos MagalhÃ£es, 269,Salvador,Bahia']
# -- linha --
# ['Posto Tic']
# ['Posto Tic', 'BRANCA']
# ['Posto Tic', 'BRANCA', 'Rodovia BR 324, 1120 - Acesso Norte,Salvador,Bahia']
# -- linha --
# ['Posto Jsm']
# ['Posto Jsm', 'SHELL']
# ['Posto Jsm', 'SHELL', 'Av. Luiz Eduardo MagalhÃ£es, s/nÂº,Salvador,Bahia']
# -- linha --
# ['Posto Jaqueira']
# ['Posto Jaqueira', 'SHELL']
# ['Posto Jaqueira', 'SHELL', 'Rodovia BR-324, Km 4.8,Salvador,Bahia']
# -- linha --
# ['Posto Trevo San Martin']
# ['Posto Trevo San Martin', 'BR']
# ['Posto Trevo San Martin', 'BR', 'Av. San Martin, 450,Salvador,Bahia']
# -- linha --
# ['Posto OgunjÃ¡']
# ['Posto OgunjÃ¡', 'BRANCA']
# ['Posto OgunjÃ¡', 'BRANCA', 'Av. GraÃ§a Lessa, 362,Salvador,Bahia']
# -- linha --
# ['Posto Gnc Paralela Ii']
# ['Posto Gnc Paralela Ii', 'BRANCA']
# ['Posto Gnc Paralela Ii', 'BRANCA', 'Av. Luis Viana Filho, 10.841,Salvador,Bahia']
# -- linha --
# ['Posto Leiro']
# ['Posto Leiro', 'BR']
# ['Posto Leiro', 'BR', 'Av. Luis Vianna Filho, 385,Salvador,Bahia']
# -- linha --
# ['Posto Sb']
# ['Posto Sb', 'SHELL']
# ['Posto Sb', 'SHELL', 'Av. Luiz Viana Filho, Lote 01,Salvador,Bahia']
# -- linha --
# ['Posto Itapoan Alphavi']
# ['Posto Itapoan Alphavi', 'BRANCA']
# ['Posto Itapoan Alphavi', 'BRANCA', 'Av. Luiz Viana Filho, Km 8,Salvador,Bahia']
# -- linha --
# ['Macro Posto']
# ['Macro Posto', 'BRANCA']
# ['Macro Posto', 'BRANCA', 'Rodovia BR-324, Km 9,Salvador,Bahia']
# -- linha --
# ['Posto Porto Seco PirajÃ¡']
# ['Posto Porto Seco PirajÃ¡', 'BR']
# ['Posto Porto Seco PirajÃ¡', 'BR', 'Rodovia BR-324, Km 9,Salvador,Bahia']
# -- linha --
# ['Posto Quatro']
# ['Posto Quatro', 'BR']
# ['Posto Quatro', 'BR', 'Av. Aliomar Baleeiro, 578,Salvador,Bahia']
# -- linha --
# ['Posto Sodic PirajÃ¡']
# ['Posto Sodic PirajÃ¡', 'SHELL']
# ['Posto Sodic PirajÃ¡', 'SHELL', 'BR-324, Km 08 - Sentido Salvador - Feira de Santana,Salvador,Bahia']
# -- linha --
# ['Posto Grande Aven']
# ['Posto Grande Aven', 'BR']
# ['Posto Grande Aven', 'BR', 'Av. OtÃ¡vio Mangabeira, 429,Salvador,Bahia']
# -- linha --
# ['Posto ItajaÃ\xad']
# ['Posto ItajaÃ\xad', 'SHELL']
# ['Posto ItajaÃ\xad', 'SHELL', 'Av. Prof. MagalhÃ£es Neto, 1338,Salvador,Bahia']
# -- linha --
# ['Posto Plus Brasil']
# ['Posto Plus Brasil', 'BRANCA']
# ['Posto Plus Brasil', 'BRANCA', 'Av. San Martin, 161,Salvador,Bahia']
# -- linha --
# ['Posto Flamma']
# ['Posto Flamma', 'SHELL']
# ['Posto Flamma', 'SHELL', 'Av. Heitor Dias, 636,Salvador,Bahia']
# -- linha --
# ['Posto ChaminÃ©']
# ['Posto ChaminÃ©', 'SHELL']
# ['Posto ChaminÃ©', 'SHELL', 'Rua MarquÃªs de Monte Santo, 50,Salvador,Bahia']
# -- linha --
# ['Posto Mataripe Xii']
# ['Posto Mataripe Xii', 'BR']
# ['Posto Mataripe Xii', 'BR', 'Av. AntÃ´nio Carlos MagalhÃ£es, s/nÂº,Salvador,Bahia']
# -- linha --
# ['Posto SÃ£o Caetano']
# ['Posto SÃ£o Caetano', 'BRANCA']
# ['Posto SÃ£o Caetano', 'BRANCA', 'Ladeira do Camurujipe, s/nÂº,Salvador,Bahia']
# -- linha --
# ['Posto ItajubÃ¡']
# ['Posto ItajubÃ¡', 'BR']
# ['Posto ItajubÃ¡', 'BR', 'Av. Arnaldo Lopes Silva, 736,Salvador,Bahia']
# -- linha --
# ['Posto KalilÃ¢ndia Flamboyan']
# ['Posto KalilÃ¢ndia Flamboyan', 'SHELL']
# ['Posto KalilÃ¢ndia Flamboyan', 'SHELL', 'Av. Luis Viana Filho, 7.419,Salvador,Bahia']
# -- linha --
# ['Posto Paraki']
# ['Posto Paraki', 'BR']
# ['Posto Paraki', 'BR', 'Rodovia BA-093, Km 1,SimÃµes Filho,Bahia']
# -- linha --
# ['Posto Ceasa']
# ['Posto Ceasa', 'BR']
# ['Posto Ceasa', 'BR', 'Rodovia CIA/Aeroporto, Km 05,SimÃµes Filho,Bahia']
# -- linha --

# %%
df_postos = pd.DataFrame(linha, columns=['nome','bandeira','endereco'])

# %%
# df_postos.to_csv('postos.csv')

# %%
df_postos = pd.read_csv('postos-2018_02.csv',sep=';',encoding='latin-1')
# df_postos = pd.read_csv('postos.csv')
df_postos.head()
# Out:
#     UF Município                                             Bairro Endereço  \
# 0  NaN       NaN  AGÊNCIA NACIONAL DO PETRÓLEO, GÁS NATURAL E BI...      NaN
# 1  NaN       NaN  SUPERINTENDÊNCIA DE FISCALIZAÇÃO DO ABASTECIME...      NaN
# 2  NaN       NaN         RELAÇÃO DE AGENTES ECONÔMICOS FISCALIZADOS      NaN
# 3  NaN       NaN  PERÍODO: FEVEREIRO/2018 - 1.477 AÇÕES DE FISCA...      NaN
# 4  NaN       NaN                                                NaN      NaN
#
#   CNPJ Razão Social Atividades Aurorizadas Data  \
# 0  NaN          NaN                    NaN  NaN
# 1  NaN          NaN                    NaN  NaN
# 2  NaN          NaN                    NaN  NaN
# 3  NaN          NaN                    NaN  NaN
# 4  NaN          NaN                    NaN  NaN
#
#                                                   DF Resultados
# 0  Atenção: Os agentes autuados possuem direito a...        NaN
# 1                                                NaN        NaN
# 2                                                NaN        NaN
# 3                                                NaN        NaN
# 4                                                NaN        NaN

# %%
df_postos[df_postos.Bairro == 'PITUBA']
# Out:
#         UF Município  Bairro                                      Endereço  \
# 346  BAHIA  SALVADOR  PITUBA      AVENIDA ANTONIO CARLOS MAGALHAES, 0, S/N
# 382  BAHIA  SALVADOR  PITUBA        AVENIDA ANTÔNIO CARLOS MAGALHÃES, 4451
# 387  BAHIA  SALVADOR  PITUBA  AVENIDA PROF. MAGALHÃES NETO, GLEBA 20, 1338
#
#                    CNPJ                                    Razão Social  \
# 346  96.766.340/0001-05    CCS COMERCIO DE COMBUSTIVEIS E SERVICOS LTDA
# 382  00.560.882/0001-40  POSTO DE ABASTECIMENTO E SERVIÇOS NOTA 10 LTDA
# 387  63.287.262/0001-07                POSTO DE COMBUSTIVEL ITAJAI LTDA
#
#     Atividades Aurorizadas        Data      DF  \
# 346       POSTO REVENDEDOR  05/02/2018  524791
# 382       POSTO REVENDEDOR  03/02/2018  524782
# 387       POSTO REVENDEDOR  02/02/2018  524781
#
#                                             Resultados
# 346   -  Ação de fiscalização sem registro de ocorr...
# 382   -  Ação de fiscalização sem registro de ocorr...
# 387   -  Ação de fiscalização sem registro de ocorr...

# %%
end_teste
teste = df_post.head(1)
param = teste.Endereço + ',' + teste.UF
param.values[0]
# Out:
# 'AVENIDA GETULIO VARGAS, 1743,ACRE'

# %%
posto = geolocator.geocode('Rodovia BR-101 Km 110.5 - s/n,Alagoinhas,Bahia')

# %%
posto

# %%
geolocator.geocode("175 5th Avenue NYC")
# Out:
# Location(Flatiron Building, 175, 5th Avenue, Flatiron District, Manhattan Community Board 5, Manhattan, New York County, NYC, New York, 10010, United States of America, (40.7410861, -73.9896298241625, 0.0))
