# %%
pip install pymongo
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
from pymongo import MongoClient
import chardet
import json
from bson import json_util
from pprint import pprint

# %%
# client = MongoClient('172.18.0.2', port=27017, %pwd='example')
client = MongoClient('mongodb://root:example@172.18.0.2:27017/')
db = client.viagens_db
viagens = db.viagens

# %%
df = pd.read_csv('viagensinstitucionais-2018-11-21.csv',delimiter=';', encoding = 'utf8')

# %%
dados = df.to_json('saida.json',orient='records')
df = pd.read_json('saida.json')

# %%
lst = [x.strip() for x in df.columns]
df.columns =  lst
df.columns
# Out:
# Index(['regra_tarifaria', 'nome_orgao_solicitante', 'nome_orgao_superior',
#        'companhia_aerea', 'numero_pcdp', 'cancelado', 'classe_tarifaria',
#        'codigo_orgao_solicitante', 'codigo_orgao_superior', 'data_embarque',
#        'data_emissao', 'diferenca_tarifa', 'localizador', 'no_show',
#        'percentual_desconto_aplicado', 'remarcado', 'situacao_bilhete',
#        'valor_bilhete', 'valor_multas', 'valor_reembolso',
#        'valor_tarifa_comercial', 'valor_tarifa_embarque',
#        'valor_tarifa_governo'],
#       dtype='object')

# %%
df = df.astype(str)
for c in lst:
    df[c] =  df[c].str.strip()

# %%
df_stat = df[[x for x in df.columns if(x.startswith('valor'))]].astype('double')

# %%
df_stat.describe()
# Out:
#        valor_bilhete  valor_multas  valor_reembolso  valor_tarifa_comercial  \
# count     663.000000    663.000000       663.000000              663.000000
# mean      766.663710     10.585385        40.652971              753.136561
# std       428.659348     82.025817       198.485155              438.339221
# min        95.890000      0.000000         0.000000                0.000000
# 25%       424.730000      0.000000         0.000000              408.900000
# 50%       706.750000      0.000000         0.000000              694.900000
# 75%       982.900000      0.000000         0.000000              978.900000
# max      3056.470000   1262.900000      2006.540000             2995.900000
#
#        valor_tarifa_embarque  valor_tarifa_governo
# count             663.000000            663.000000
# mean               31.082323            735.581388
# std                 6.823910            427.068885
# min                 0.000000             66.400000
# ...

# %%
viagens.insert_many(df.to_dict('records'))

# %%
for post in viagens.find():
       pprint(post)
# Out:
# {'_id': ObjectId('5daa6456c10bd9758ee90c99'),
#  'cancelado': 'Sim',
#  'classe_tarifaria': 'L,L',
#  'codigo_orgao_solicitante': '21520.0',
#  'codigo_orgao_superior': '3',
#  'companhia_aerea': 'AZUL LINHAS AÉREAS BRASILEIRA',
#  'data_embarque': '10/08/2019',
#  'data_emissao': '05/07/2019',
#  'diferenca_tarifa': '0.0',
#  'localizador': 'KIHJSN',
#  'no_show': 'Não',
#  'nome_orgao_solicitante': 'Unidade Estadual do IBGE em Rondônia',
#  'nome_orgao_superior': 'Fundação Instituto Brasileiro de Geografia e '
#                         'Estatística',
#  'numero_pcdp': '014534/19-1C',
#  'percentual_desconto_aplicado': '5.0',
#  'regra_tarifaria': 'https://www.voeazul.com.br/para-sua-viagem/informacoes-para-viajar/remarcacao--cancelamento',
#  'remarcado': 'Não',
#  'situacao_bilhete': 'Cancelado',
#  'valor_bilhete': '782.43',
#  'valor_multas': '0.0',
#  'valor_reembolso': '0.0',
#  'valor_tarifa_comercial': '790.9',
#  'valor_tarifa_embarque': '31.08',
# ...
